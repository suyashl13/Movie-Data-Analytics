# %% [markdown]
# # Data analytics on movie dataset.
# This is data analytics performed on movies dataset.

# %% [markdown]
# #### Import Libraries

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### 1. Read your CSV file (Dataset) into DataFrame as df

# %%
movies_dataset = pd.read_csv('./movie.csv')
movies_dataset.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4  Color        Doug Walker                     0.0      20.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
pd.Series(movies_dataset.keys())
# Out:
# 0                         color
# 1                 director_name
# 2        num_critic_for_reviews
# 3                      duration
# 4       director_facebook_likes
# 5        actor_3_facebook_likes
# 6                  actor_2_name
# 7        actor_1_facebook_likes
# 8                         gross
# 9                        genres
# 10                 actor_1_name
# 11                  movie_title
# 12              num_voted_users
# 13    cast_total_facebook_likes
# 14                 actor_3_name
# 15         facenumber_in_poster
# 16                plot_keywords
# 17              movie_imdb_link
# 18         num_user_for_reviews
# 19                     language
# 20                      country
# 21               content_rating
# 22                       budget
# 23                   title_year
# 24       actor_2_facebook_likes
# 25                   imdb_score
# 26                 aspect_ratio
# 27         movie_facebook_likes
# dtype: object

# %% [markdown]
# #### 2. Get the total count of Color and Black/White movies

# %%
movies_dataset['color'].value_counts()
# Out:
# Color               4816
#  Black and White     209
# Name: color, dtype: int64

# %% [markdown]
# #### 3. Plot bar graph and Pie chart for the above movies count

# %%
sns.countplot(x='color',data=movies_dataset)
# Out:
# <Axes: xlabel='color', ylabel='count'>

# %% [markdown]
# #### 4. Display all the unique director names

# %%
movies_dataset['director_name'].value_counts()
# Out:
# Steven Spielberg    26
# Woody Allen         22
# Clint Eastwood      20
# Martin Scorsese     20
# Ridley Scott        17
#                     ..
# John Crowley         1
# Rob Pritts           1
# David S. Ward        1
# R.J. Cutler          1
# Daniel Hsia          1
# Name: director_name, Length: 2398, dtype: int64

# %% [markdown]
# #### 5. Display all the diffent generes of movie

# %%
m_genre = set()
for item in movies_dataset['genres']:
    for i in item.split('|'):
        m_genre.add(i)
            
pd.Series(list(m_genre))
# Out:
# 0         Mystery
# 1         Musical
# 2            News
# 3          Horror
# 4         History
# 5         Western
# 6           Drama
# 7       Animation
# 8         Fantasy
# 9       Film-Noir
# 10      Biography
# 11       Thriller
# 12            War
# 13          Sport
# 14     Reality-TV
# 15         Sci-Fi
# 16    Documentary
# 17          Music
# 18      Game-Show
# 19         Family
# 20         Comedy
# 21         Action
# 22      Adventure
# 23          Short
# 24        Romance
# 25          Crime
# dtype: object

# %% [markdown]
# #### 6. Get the total count of movies released in New Zealand

# %%
movies_dataset['country'].value_counts()['New Zealand']
# Out:
# 15

# %% [markdown]
# #### 7. List all the movies with all details which were released in New Zealand

# %%
movies_dataset.copy().loc[movies_dataset['country'] == 'New Zealand']
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 20    Color     Peter Jackson                   422.0     164.0
# 25    Color     Peter Jackson                   446.0     201.0
# 270   Color     Peter Jackson                   297.0     171.0
# 1174  Color        Sngmoo Lee                    95.0     100.0
# 1993  Color   Roger Donaldson                   126.0     127.0
# 2049  Color     Peter Jackson                   446.0     201.0
# 3469  Color      Jane Campion                    83.0     121.0
# 3573  Color         Ian Sharp                    12.0     102.0
# 3775  Color     Peter Jackson                    93.0     108.0
# 3840  Color    Robert Sarkies                    43.0     100.0
# 3876  Color         Niki Caro                   149.0     101.0
# 4354  Color        John Laing                     NaN      86.0
# 4438  Color  Gerard Johnstone                   166.0     107.0
# 4590  Color    Anthony Powell                    31.0      91.0
# ...

# %% [markdown]
# #### 8. Dispaly the bargraph with count for the movies which are released in Austraial, Germany and Japan

# %%
bar_data = {
    'Australia':movies_dataset['country'].value_counts()['Australia'],
    'Germany':movies_dataset['country'].value_counts()['Germany'],
    'Japan':movies_dataset['country'].value_counts()['Japan'],
}

plt.bar(
    bar_data.keys(),
    bar_data.values(),
)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# #### 9. Get the list of 5 movies with highest budget

# %%
movies_dataset.copy().sort_values(by=['budget'], ascending=False).head(5)[['movie_title','budget']]
# Out:
#              movie_title        budget
# 2988           The Host   1.221550e+10
# 3859     Lady Vengeance   4.200000e+09
# 3005           Fateless   2.500000e+09
# 2323  Princess Mononoke   2.400000e+09
# 2334           Steamboy   2.127520e+09

# %% [markdown]
# #### 10. Dispaly the list of movies which are released in year 2009

# %%
movies_dataset.copy().loc[movies_dataset['title_year'] == 2009][['movie_title','title_year']]
# Out:
#                                   movie_title  title_year
# 0                                     Avatar       2009.0
# 9     Harry Potter and the Half-Blood Prince       2009.0
# 36       Transformers: Revenge of the Fallen       2009.0
# 44                      Terminator Salvation       2009.0
# 60                                      2012       2009.0
# ...                                       ...         ...
# 4971              The Last House on the Left       2009.0
# 5003                      The Exploding Girl       2009.0
# 5007                            Down Terrace       2009.0
# 5014                                 Rampage       2009.0
# 5023                        Breaking Upwards       2009.0
#
# [260 rows x 2 columns]

# %% [markdown]
# #### 11. Dispaly the list of movies which are released in year 2009 and does not belgon to USA

# %%
movies_dataset.copy().loc[movies_dataset['title_year'] == 2009].loc[movies_dataset['country'] != 'USA'][['movie_title','title_year', 'country']]
# Out:
#                                   movie_title  title_year    country
# 9     Harry Potter and the Half-Blood Prince       2009.0         UK
# 302                Where the Wild Things Are       2009.0    Germany
# 504                                   Oceans       2009.0     France
# 636                                    Agora       2009.0      Spain
# 696                                Astro Boy       2009.0  Hong Kong
# ...                                       ...         ...        ...
# 4701                             Starsuckers       2009.0         UK
# 4825                                Dogtooth       2009.0     Greece
# 4872                                    Exam       2009.0         UK
# 5007                            Down Terrace       2009.0         UK
# 5014                                 Rampage       2009.0     Canada
#
# [76 rows x 3 columns]

# %% [markdown]
# #### 12. Get the Count for movies which has duration less than 100 and greater than 100 and plot the bar graph for same

# %%
mov_count = {
    'movies_less_that_100' : movies_dataset['duration'].copy().loc[movies_dataset['duration'] < 100].count(),
    'movies_more_that_100' : movies_dataset['duration'].copy().loc[movies_dataset['duration'] > 100].count(),
}

# %%
plt.bar(
    mov_count.keys(),
    mov_count.values(),
)
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# #### 13. List the top 10 director names for highest director-facebook likes

# %%
movies_dataset.copy().sort_values(by=['director_facebook_likes'], ascending=False).head(10)[['movie_title','director_facebook_likes']]
# Out:
#                            movie_title  director_facebook_likes
# 3672                          Don Jon                   23000.0
# 66                    The Dark Knight                   22000.0
# 97                          Inception                   22000.0
# 3716                          Memento                   22000.0
# 1066                         Insomnia                   22000.0
# 96                       Interstellar                   22000.0
# 1233                     The Prestige                   22000.0
# 3               The Dark Knight Rises                   22000.0
# 120                     Batman Begins                   22000.0
# 364   The Girl with the Dragon Tattoo                   21000.0

# %% [markdown]
# #### 14. Display the list of movies for top 5 with movie-facebook likes

# %%
top_5_fblike_movies = movies_dataset.copy().sort_values(by=['movie_facebook_likes'], ascending=False).head(5)[['movie_title','movie_facebook_likes']]
top_5_fblike_movies
# Out:
#                              movie_title  movie_facebook_likes
# 96                         Interstellar                 349000
# 296                    Django Unchained                 199000
# 10   Batman v Superman: Dawn of Justice                 197000
# 128                  Mad Max: Fury Road                 191000
# 179                        The Revenant                 190000

# %% [markdown]
# #### 15. Plot the graph for top 5 movie facebook likes

# %%
plt.bar(
    top_5_fblike_movies['movie_title'].values,
    top_5_fblike_movies['movie_facebook_likes'].values,
    width=0.5
)
# Out:
# <BarContainer object of 5 artists>
